# %%
import rdflib
import pandas as pd
from rapidfuzz import fuzz, process
import obonet

# %%
preds = pd.read_parquet("../preds_strainselect.pqt")

# %%
vcs = preds.value_counts(["ner","word_qc"]).reset_index().sort_values(["ner","count"],ascending=False)

# %% [markdown]
# # MEDIUM

# %% [markdown]
# ## GMO

# %%
# Load the ontology file
g = rdflib.Graph()
g.parse("ontologies/gmo/gmo.ttl", format="ttl")
# Out:
# <Graph identifier=N9befc49c08154039b384f01240394ec7 (<class 'rdflib.graph.Graph'>)>

# %%
# Extract relevant data including all predicates found
data = []

# Define initially known relevant predicates and any new ones found
predicates = {
    rdflib.RDFS.label: 'label',
    rdflib.URIRef('http://www.w3.org/2004/02/skos/core#altLabel'): 'altLabel',
    rdflib.RDFS.subClassOf: 'subClassOf',
    rdflib.OWL.disjointWith: 'disjointWith',
    rdflib.URIRef('http://purl.org/dc/terms/identifier'): 'identifier',
    rdflib.RDFS.comment: 'comment',
    rdflib.SKOS.prefLabel: 'prefLabel',
    rdflib.SKOS.definition: 'definition',
    rdflib.URIRef('http://purl.org/dc/terms/bibliographicCitation'): 'bibliographicCitation',
    rdflib.URIRef('http://purl.org/dc/terms/contributor'): 'contributor',
    rdflib.URIRef('http://purl.org/dc/terms/creator'): 'creator',
    rdflib.URIRef('http://purl.org/dc/terms/date'): 'date',
    rdflib.URIRef('http://purl.org/dc/terms/description'): 'description',
    rdflib.URIRef('http://purl.org/dc/terms/references'): 'references',
    rdflib.URIRef('http://purl.org/dc/terms/title'): 'title',
    rdflib.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'): 'type',
    rdflib.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'): 'domain',
    rdflib.URIRef('http://www.w3.org/2000/01/rdf-schema#range'): 'range',
    rdflib.URIRef('http://www.w3.org/2000/01/rdf-schema#seeAlso'): 'seeAlso',
    rdflib.URIRef('http://www.w3.org/2002/07/owl#versionIRI'): 'versionIRI',
    rdflib.URIRef('http://www.w3.org/2002/07/owl#versionInfo'): 'versionInfo',
    rdflib.URIRef('http://www.w3.org/2004/02/skos/core#historyNote'): 'historyNote',
    rdflib.URIRef('http://www.w3.org/2004/02/skos/core#note'): 'note'
}

for s, p, o in g:
    if p in predicates:
        identifier = s.split('/')[-1]
        value = str(o)
        predicate = predicates[p]
        data.append({'identifier': identifier, 'value': value, 'type': predicate})

# Convert the extracted data into a DataFrame
gmo = pd.DataFrame(data)

# %%
gmo
# Out:
#       identifier                                             value        type
# 0     GMO_001450      http://www.ncbi.nlm.nih.gov/pccompound/61701     seeAlso
# 1     GMO_001666              http://en.wikipedia.org/wiki/Trypsin     seeAlso
# 2     GMO_001731               http://www.w3.org/2002/07/owl#Class        type
# 3     GMO_001774              http://purl.jp/bio/10/gmo/GMO_001773  subClassOf
# 4     GMO_001933              http://purl.jp/bio/10/gmo/GMO_000002  subClassOf
# ...          ...                                               ...         ...
# 8611  GMO_000001                                            Medium       label
# 8612  GMO_001635                                      Rabbit serum       label
# 8613  GMO_001861                           alpha-Ketoglutaric acid  definition
# 8614  GMO_000110  http://www.w3.org/2002/07/owl#AnnotationProperty        type
# 8615  GMO_001399                           Bacteriological peptone   prefLabel
#
# [8616 rows x 3 columns]

# %%
gmo[gmo["type"]=="label"].identifier.unique().shape
# Out:
# (1040,)

# %%
gmo_db = pd.read_csv("ontologies/GMO.csv")

# %%
gmo[gmo.value.str.contains("tryptic soy broth")]
# Out:
# Empty DataFrame
# Columns: [identifier, value, type]
# Index: []

# %%
gmo[gmo.identifier == "GMO_000019"]
# Out:
#       identifier                                 value        type
# 1311  GMO_000019                            GMO_000019  identifier
# 1701  GMO_000019               Prepared culture medium       label
# 3210  GMO_000019               Prepared culture medium   prefLabel
# 7004  GMO_000019   http://www.w3.org/2002/07/owl#Class        type
# 8289  GMO_000019  http://purl.jp/bio/10/gmo/GMO_000002  subClassOf

# %%
gmo_db[gmo_db["Preferred Label"].str.contains("")]
# Out:
# Empty DataFrame
# Columns: [Class ID, Preferred Label, Synonyms, Definitions, Obsolete, CUI, Semantic Types, Parents, amount, concentration, constituent, has property, has role, http://data.bioontology.org/metadata/prefixIRI, http://purl.org/dc/terms/bibliographicCitation, http://purl.org/dc/terms/contributor, http://purl.org/dc/terms/creator, http://purl.org/dc/terms/date, http://purl.org/dc/terms/description, http://purl.org/dc/terms/identifier, http://purl.org/dc/terms/references, http://purl.org/dc/terms/title, http://www.w3.org/2004/02/skos/core#altLabel, http://www.w3.org/2004/02/skos/core#definition, http://www.w3.org/2004/02/skos/core#historyNote, http://www.w3.org/2004/02/skos/core#note, http://www.w3.org/2004/02/skos/core#prefLabel, is a medium type, is composed of, medium description, medium ID, medium name, medium URL, original description]
# Index: []
#
# [0 rows x 34 columns]

# %%
values = gmo_db['Preferred Label'].tolist()

# %%
preds_medium = preds[preds.ner=="MEDIUM"]

# %%
preds_medium_vc = preds_medium.word_qc.value_counts().reset_index()

# %%
preds_medium_vc
# Out:
#                          word_qc  count  \
# 0                             lb  47756
# 1                            tsb  12523
# 2                       lb broth  11208
# 3                            bhi   8144
# 4                  luria-bertani   8105
# ...                          ...    ...
# 43295                 ay3706-ngm      1
# 43296                   op50-ngm      1
# 43297  citrated sheep blood agar      1
# 43298      flask standard medium      1
# 43299          selective dropout      1
#
#                                         best_match
# 0                           (lb medium, 90.0, 305)
# 1                   (quaker white oats, 72.0, 276)
# 2               (difco lb broth, lennox, 90.0, 36)
# 3                             (biphenyl, 72.0, 89)
# 4                                (edta, 67.5, 705)
# ...                                            ...
# 43295                             (mes, 45.0, 141)
# 43296               (mops, 60.00000000000001, 168)
# 43297                            (agar, 90.0, 721)
# 43298  (medium type based on consistency, 85.5, 6)
# 43299     (selective medium, 72.72727272727273, 4)
#
# [43300 rows x 3 columns]

# %%
preds_medium_vc['best_match'] = preds_medium_vc['word_qc'].apply(lambda x: process.extractOne(x, [i.lower() for i in values], scorer=fuzz.WRatio))

# %%
preds_medium_vc['best_match_db'] = preds_medium_vc['word_qc'].apply(lambda x: process.extractOne(x, [i.lower() for i in gmo_db["Preferred Label"].to_list()], scorer=fuzz.WRatio))

# %%
preds_medium_vc
# Out:
#                          word_qc  count  \
# 0                             lb  47756
# 1                            tsb  12523
# 2                       lb broth  11208
# 3                            bhi   8144
# 4                  luria-bertani   8105
# ...                          ...    ...
# 43295                 ay3706-ngm      1
# 43296                   op50-ngm      1
# 43297  citrated sheep blood agar      1
# 43298      flask standard medium      1
# 43299          selective dropout      1
#
#                                         best_match  \
# 0                           (lb medium, 90.0, 305)
# 1                   (quaker white oats, 72.0, 276)
# 2               (difco lb broth, lennox, 90.0, 36)
# 3                             (biphenyl, 72.0, 89)
# 4                                (edta, 67.5, 705)
# ...                                            ...
# 43295                             (mes, 45.0, 141)
# 43296               (mops, 60.00000000000001, 168)
# 43297                            (agar, 90.0, 721)
# 43298  (medium type based on consistency, 85.5, 6)
# 43299     (selective medium, 72.72727272727273, 4)
#
#                                      best_match_db
# 0                           (lb medium, 90.0, 305)
# 1                   (quaker white oats, 72.0, 276)
# 2               (difco lb broth, lennox, 90.0, 36)
# 3                             (biphenyl, 72.0, 89)
# 4                                (edta, 67.5, 705)
# ...                                            ...
# 43295                             (mes, 45.0, 141)
# 43296               (mops, 60.00000000000001, 168)
# 43297                            (agar, 90.0, 721)
# 43298  (medium type based on consistency, 85.5, 6)
# 43299     (selective medium, 72.72727272727273, 4)
#
# [43300 rows x 4 columns]

# %% [markdown]
# ## MCO

# %%
# Load the ontology file
graph = obonet.read_obo('ontologies/Microbial-Conditions-Ontology/mco.obo')

# %%
labels = [data['name'] for _, data in graph.nodes(data=True)]

# %%
names = []
synonyms = []

for _, data in graph.nodes(data=True):
	name = data.get('name')
	if name:
		names.append(name)
	synonyms.extend(data.get('synonym', []))

# %%
names_series = pd.Series(names).str.lower()

# %%
names_series[names_series.str.contains("")]
# Out:
# Series([], dtype: object)

# %%
graph.nodes(data=True)['MICRO:0000558']["name"]
# Out:
# 'MacConkey agar'

# %% [markdown]
# # CHEBI

# %%
chebi = pd.read_csv("ontologies/CHEBI.csv")
# Out:
# /var/folders/08/0076z2nx1y7bs97dcwb0_4ym0000gq/T/ipykernel_49122/1197350040.py:1: DtypeWarning: Columns (30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   chebi = pd.read_csv("ontologies/CHEBI.csv")

# %%
chebi[chebi["Preferred Label"].str.contains("LB")]
# Out:
#                                            Class ID  \
# 34715   http://purl.obolibrary.org/obo/CHEBI_185775
# 82185    http://purl.obolibrary.org/obo/CHEBI_47076
# 109840  http://purl.obolibrary.org/obo/CHEBI_178642
# 122826  http://purl.obolibrary.org/obo/CHEBI_140875
# 137096  http://purl.obolibrary.org/obo/CHEBI_214634
# 144810  http://purl.obolibrary.org/obo/CHEBI_167660
# 186331   http://purl.obolibrary.org/obo/CHEBI_46269
# 199009  http://purl.obolibrary.org/obo/CHEBI_188257
#
#                                           Preferred Label  \
# 34715                                          ALBIZZIINE
# 82185   N-(3-AMINOPROPYL)-N-[(R)-(3-BENZYL-5-CHLORO-4-...
# 109840                            LBPA(16:1(9Z)/18:1(9Z))
# 122826                                           SKLB-677
# 137096                                             MC-LBu
# 144810                                            LB42908
# 186331       4,4,4-TRIFLUORO-1-THIEN-2-YLBUTANE-1,3-DIONE
# 199009                                        SLBPA(42:0)
#
#                                                  Synonyms  \
# 34715            2-amino-3-(carbamoylamino)propanoic acid
# 82185                                                 NaN
# 109840  [(2S)-1-[[(2S)-2-[(Z)-hexadec-9-enoyl]oxy-3-hy...
# 122826  1-(5-tert-butyl-1,2-oxazol-3-yl)-3-[3-fluoro-4...
# 137096  (5R,8S,11R,12S,15S,18S,19S,22R)-15-ethyl-18-[(...
# 144810  LB-42908|(1-((1-(benzo[d][1,3]dioxol-5-ylmethy...
# 186331                                                NaN
# 199009  [(2S)-3-[[(2S)-2,3-di(tetradecanoyloxy)propoxy...
#
#                                               Definitions  Obsolete  CUI  \
# 34715                                                 NaN     False  NaN
# 82185                                                 NaN     False  NaN
# 109840                                                NaN     False  NaN
# 122826  A member of the class of phenylureas that is u...     False  NaN
# 137096                                                NaN     False  NaN
# 144810  A member of the class of pyrrolecarboxamides t...     False  NaN
# 186331                                                NaN     False  NaN
# 199009                                                NaN     False  NaN
#
#         Semantic Types                                            Parents  \
# 34715              NaN         http://purl.obolibrary.org/obo/CHEBI_33704
# 82185              NaN         http://purl.obolibrary.org/obo/CHEBI_88341
# 109840             NaN         http://purl.obolibrary.org/obo/CHEBI_24360
# 122826             NaN  http://purl.obolibrary.org/obo/CHEBI_134043|ht...
# 137096             NaN         http://purl.obolibrary.org/obo/CHEBI_16670
# 144810             NaN  http://purl.obolibrary.org/obo/CHEBI_46844|htt...
# 186331             NaN         http://purl.obolibrary.org/obo/CHEBI_76224
# 199009             NaN         http://purl.obolibrary.org/obo/CHEBI_24360
#
#         BRAND NAME                           database_cross_reference  ...  \
# 34715          NaN                      Chemspider:308985|KEGG:C08264  ...
# 82185          NaN                                                NaN  ...
# 109840         NaN                   LIPID_MAPS_instance:LMGP04100004  ...
# 122826         NaN                                      PMID:26497577  ...
# 137096         NaN                                                NaN  ...
# 144810         NaN  PMID:11714612|PMID:24059235|PMID:15812228|Chem...  ...
# 186331         NaN                                                NaN  ...
# 199009         NaN  Chemspider:113377844|LIPID_MAPS_instance:LMGP0...  ...
#
#        INN is conjugate acid of  is conjugate base of is enantiomer of  \
# 34715  NaN                  NaN                   NaN              NaN
# 82185  NaN                  NaN                   NaN              NaN
# 109840 NaN                  NaN                   NaN              NaN
# 122826 NaN                  NaN                   NaN              NaN
# 137096 NaN                  NaN                   NaN              NaN
# 144810 NaN                  NaN                   NaN              NaN
# 186331 NaN                  NaN                   NaN              NaN
# 199009 NaN                  NaN                   NaN              NaN
#
#        is substituent group from is tautomer of IUPAC NAME shorthand  \
# 34715                        NaN            NaN        NaN       NaN
# 82185                        NaN            NaN        NaN       NaN
# 109840                       NaN            NaN        NaN       NaN
# 122826                       NaN            NaN        NaN       NaN
# 137096                       NaN            NaN        NaN       NaN
# 144810                       NaN            NaN        NaN       NaN
# 186331                       NaN            NaN        NaN       NaN
# 199009                       NaN            NaN        NaN       NaN
#
#         subset_property synonym_type_property
# 34715               NaN                   NaN
# 82185               NaN                   NaN
# 109840              NaN                   NaN
# 122826              NaN                   NaN
# 137096              NaN                   NaN
# 144810              NaN                   NaN
# 186331              NaN                   NaN
# 199009              NaN                   NaN
#
# [8 rows x 57 columns]

# %%
k
