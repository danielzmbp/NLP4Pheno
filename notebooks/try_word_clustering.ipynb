# %%
from rapidfuzz import fuzz
from rapidfuzz import process
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
df = pd.read_parquet("../preds_strainselect.pqt")

# %%
df = df.drop(columns=["label_rel","label"])

# %%
df = df.rename(columns={"score":"ner_score",})

# %%
df["ner"].unique()
# Out:
# array(['ISOLATE', 'MEDIUM', 'PHENOTYPE', 'ORGANISM', 'COMPOUND', 'EFFECT',
#        'DISEASE', 'SPECIES'], dtype=object)

# %%
words = df[df["ner"]=="ORGANISM"].word_qc.value_counts()
query_words = words[(words > 4)].index
all_words = words.index

# %%
cutoff = 95

# %%
result = process.cdist(query_words, all_words, scorer=fuzz.token_sort_ratio, score_cutoff=cutoff, workers=10)
indices = np.argwhere(result >= cutoff)

# %%
word_indices = list(zip(all_words[indices[:,0]], all_words[indices[:,1]]))
matchesdf = pd.DataFrame(word_indices)

# %%
scores = result[indices[:,0], indices[:,1]]
matchesdf['score'] = scores

# %%
unique_matches = matchesdf[matchesdf[0] != matchesdf[1]]

# %%
word_counts = df.word_qc.value_counts()
unique_matches.loc[:, 'total_count_0'] = unique_matches[0].map(word_counts)
unique_matches.loc[:, 'total_count_1'] = unique_matches[1].map(word_counts)
# Out:
# /var/folders/08/0076z2nx1y7bs97dcwb0_4ym0000gq/T/ipykernel_37892/3398022425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_matches.loc[:, 'total_count_0'] = unique_matches[0].map(word_counts)
# /var/folders/08/0076z2nx1y7bs97dcwb0_4ym0000gq/T/ipykernel_37892/3398022425.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_matches.loc[:, 'total_count_1'] = unique_matches[1].map(word_counts)

# %%
unique_matches.loc[:, 'consensus_word'] = unique_matches.apply(lambda x: x[0] if x['total_count_0'] > x['total_count_1'] else x[1], axis=1)
# Out:
# /var/folders/08/0076z2nx1y7bs97dcwb0_4ym0000gq/T/ipykernel_37892/3603133400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_matches.loc[:, 'consensus_word'] = unique_matches.apply(lambda x: x[0] if x['total_count_0'] > x['total_count_1'] else x[1], axis=1)

# %%
unique_matches
# Out:
#                                      0                                  1  \
# 8                          balb/c mice                       balb/cj mice
# 9                          balb/c mice                         balbc mice
# 10                         balb/c mice                       balb/ca mice
# 11                         balb/c mice                       balb/c, mice
# 12                         balb/c mice                       bablb/c mice
# ...                                ...                                ...
# 13423  severe combined immunodeficient  severe combined immunodeficient (
# 13424  severe combined immunodeficient   severe combined immune-deficient
# 13430                   codium fragile                    codium fragile,
# 13433                  t. subterraneum                   t. subterraneaum
# 13439                       acala nemx                        acala nem-x
#
#            score  total_count_0  total_count_1  \
# 8      95.652176           4082             39
# 9      95.238098           4082             10
# 10     95.652176           4082              3
# 11     95.652176           4082              2
# 12     95.652176           4082              1
# ...          ...            ...            ...
# 13423  96.875000              5              1
# 13424  95.238098              5              1
# 13430  96.551727              5              1
# 13433  96.774193              5              1
# 13439  95.238098              5              1
#
#                         consensus_word
# 8                          balb/c mice
# 9                          balb/c mice
# 10                         balb/c mice
# 11                         balb/c mice
# 12                         balb/c mice
# ...                                ...
# 13423  severe combined immunodeficient
# 13424  severe combined immunodeficient
# 13430                   codium fragile
# 13433                  t. subterraneum
# 13439                       acala nemx
#
# [2941 rows x 6 columns]

# %%
unique_matches.sort_values(by="score", ascending=False).iloc[-30:]
# Out:
#                            0                      1  score  total_count_0  \
# 4281    c6/36 mosquito cells   c3/36 mosquito cells   95.0             15
# 4590   conventional chickens    conventional chicks   95.0             14
# 4544     g. mellonella larva  g. mellonella) larvae   95.0             14
# 6815    rhodotorula glutinis   rhodotorula glutinus   95.0              9
# 579     raw264.7 macrophages   raw246.7 macrophages   95.0            137
# 13292   phytophthora capsica   phytophthora capsici   95.0              5
# 6518    fusarium moniliforme   fusarium moniloforme   95.0              9
# 3096     biserrula pelecinus  biserrula pelecinus l   95.0             22
# 9021    pseudosciaene crocea   pseudosciaena crocea   95.0              7
# 9037     myoporum bontioides  myoporum bontioides a   95.0              7
# 1047    cx. quinquefasciatus   c.) quinquefasciatus   95.0             70
# 1046    cx. quinquefasciatus   c. quinquesfasciatus   95.0             70
# 1031    alternaria alternata   alternaria alternate   95.0             72
# 998     triticum aestivum l.   triticum aestiuum l.   95.0             75
# 3330    scophthalmus maximus   scophthatmus maximus   95.0             20
# 5737     phoenix dactylifera  phoenix dactylifera l   95.0             11
# 8042     f. graminearum s.s.  f. graminearum s.str.   95.0              7
# 5515     brassica campestris  brassica campestris l   95.0             11
# 6787     salicornia europaea  salicornia europaea l   95.0              9
# 1586    phytophthora capsici   phytophthora capsica   95.0             45
# 9950    s. americanum sp2275   s. americanum sp2273   95.0              6
# 3902    rhizopus microsporus   rhizopus microspores   95.0             17
# 10118   sponge haliclona sp.   halicloma sp. sponge   95.0              6
# 8845    s. americanum sp2273   s. americanum sp2275   95.0              7
# 2396     plutella xylostella  plutella xylostella l   95.0             30
# 507    phytopathogenic fungi    phytopathogen fungi   95.0            167
# 2358    acanthus ilicifolius   acanthus llicifolius   95.0             30
# 455     solanum lycopersicum   solanum licopersicum   95.0            177
# 5185    fourth instar larvae   fourth-instar larvae   95.0             12
# 1962    candida parapsilosis   candida parapsolosis   95.0             47
#
#        total_count_1         consensus_word
# 4281               4   c6/36 mosquito cells
# 4590               3  conventional chickens
# 4544               2    g. mellonella larva
# 6815               1   rhodotorula glutinis
# 579                1   raw264.7 macrophages
# 13292             45   phytophthora capsici
# 6518               1   fusarium moniliforme
# 3096               2    biserrula pelecinus
# 9021               8   pseudosciaena crocea
# 9037               2    myoporum bontioides
# 1047               1   cx. quinquefasciatus
# 1046               2   cx. quinquefasciatus
# 1031               9   alternaria alternata
# 998                2   triticum aestivum l.
# 3330               1   scophthalmus maximus
# 5737               1    phoenix dactylifera
# 8042               4    f. graminearum s.s.
# 5515               2    brassica campestris
# 6787               1    salicornia europaea
# 1586               5   phytophthora capsici
# 9950               7   s. americanum sp2273
# 3902               3   rhizopus microsporus
# 10118              1   sponge haliclona sp.
# 8845               6   s. americanum sp2273
# 2396               1    plutella xylostella
# 507                3  phytopathogenic fungi
# 2358               1   acanthus ilicifolius
# 455                1   solanum lycopersicum
# 5185               8   fourth instar larvae
# 1962               1   candida parapsilosis

# %%
# Create a dictionary to group words based on common connections
grouped_words = defaultdict(list)
for _, row in unique_matches.iterrows():
    grouped_words[row['consensus_word']].append(row)

# Create a dictionary to map each consensus word to all connected words
consensus_to_words = defaultdict(set)

# Iterate through each group to check their abundances and select the consensus word
for group_key, group_values in grouped_words.items():
    # Calculate the total count for each word in the group
    total_counts = {word: sum(unique_matches[unique_matches[0] == word]['total_count_0']) + sum(unique_matches[unique_matches[1] == word]['total_count_1']) for word in [row[0] for row in group_values] + [row[1] for row in group_values]}
    # Select the word with the highest total count as the consensus word
    consensus_word = max(total_counts, key=total_counts.get)
    
    # Add all words in the group to the set of the consensus word
    for row in group_values:
        consensus_to_words[consensus_word].update([row[0], row[1]])

# Save the mapping to a file
import json
with open('consensus_to_words_mapping.json', 'w') as f:
    json.dump(
        {k: list(v) for k, v in consensus_to_words.items()},
        f,
        indent=4
    )

# %%
# Replace the "word_qc" column in the df dataframe using the consensus_to_words dictionary
df['word_qc_group'] = df['word_qc'].apply(lambda x: next((k for k, v in consensus_to_words.items() if x in v), x))

# %%
len(consensus_to_words)
# Out:
# 1369

# %%
df
# Out:
#                                           formatted_text  \
# 0      (@STRAIN$), isolated from a @ISOLATE$ that was...
# 1      1), Planothidium sp. (@STRAIN$), which was iso...
# 2      A FAW strain (@STRAIN$ 89034‐R) resistant to M...
# 3      A mesophilic @ISOLATE$ culture @STRAIN$-22 (La...
# 4      A negative control (DNA extracted from @ISOLAT...
# ...                                                  ...
# 11676  The effectiveness of @STRAIN$ was confirmed by...
# 11677  The lack of protection by the strains of @STRA...
# 11678  The lack of protection by the strains of L. ac...
# 11679  There have been reports of improved cognition,...
# 11680  This study thus indicates that @STRAIN$-1014 h...
#
#                                                     text  end_strain  \
# 0      (A18), isolated from a deep-water sediment sam...           4
# 1      1), Planothidium sp. (st. 2), which was isolat...          27
# 2      A FAW strain (MON 89034‐R) resistant to MON 89...          17
# 3      A mesophilic cheese culture CHN-22 (Lactococcu...          31
# 4      A negative control (DNA extracted from water) ...         134
# ...                                                  ...         ...
# 11676  The effectiveness of S. boulardii CNCM I-745 w...          44
# 11677  The lack of protection by the strains of L. ac...          42
# 11678  The lack of protection by the strains of L. ac...          61
# 11679  There have been reports of improved cognition,...         208
# 11680  This study thus indicates that DK-1014 has a s...          33
#
#       entity_group_strain  score_strain  start_strain  \
# 0                       B      0.931742             1
# 1                       B      0.740087            22
# 2                       B      0.521139            14
# 3                       B      0.828548            28
# 4                       B      0.924880           113
# ...                   ...           ...           ...
# 11676                   B      0.951697            21
# 11677                   B      0.571035            41
# 11678                   B      0.508241            60
# 11679                   B      0.717988           205
# 11680                   B      0.539150            31
#
#                    word_strain    end entity_group  ner_score  ...  score_rel  \
# 0                          a18   49.0            B   0.988911  ...   0.999886
# 1                        st. 2   66.0            B   0.989779  ...   0.999889
# 2                          mon  140.0            B   0.826722  ...   0.999880
# 3                          chn   19.0            B   0.944847  ...   0.999896
# 4        l. interrogans atcc^®   44.0            B   0.832074  ...   0.736157
# ...                        ...    ...          ...        ...  ...        ...
# 11676  s. boulardii cncm i-745  264.0            B   0.589171  ...   0.689224
# 11677                        l  175.0            B   0.663700  ...   0.966521
# 11678                        l  175.0            B   0.663700  ...   0.954678
# 11679                      vsl  140.0            B   0.661192  ...   0.992038
# 11680                       dk  299.0            B   0.600352  ...   0.908736
#
#                 word_strain_qc                     word_qc  score_full vertex  \
# 0                          a18  deep-water sediment sample         NaN   None
# 1                        st. 2                    peatland         NaN   None
# 2                          mon                       field         NaN   None
# 3                          chn                      cheese         NaN   None
# 4        l. interrogans atcc^®                       water         NaN   None
# ...                        ...                         ...         ...    ...
# 11676  s. boulardii cncm i-745       acute gastroenteritis         NaN   None
# 11677                        l                         nec         NaN   None
# 11678                        l                         nec         NaN   None
# 11679                      vsl                   cirrhosis         NaN   None
# 11680                       dk                      asthma         NaN   None
#
#        vertex_type StrainSelectID score_partial  score_parts  \
# 0             None           None           NaN          NaN
# 1             None           None           NaN          NaN
# 2             None           None           NaN          NaN
# 3             None           None           NaN          NaN
# 4             None           None           NaN          NaN
# ...            ...            ...           ...          ...
# 11676         None           None           NaN          NaN
# 11677         None           None           NaN          NaN
# 11678         None           None           NaN          NaN
# 11679         None           None           NaN          NaN
# 11680         None           None           NaN          NaN
#
#                     word_qc_group
# 0      deep-water sediment sample
# 1                        peatland
# 2                           field
# 3                          cheese
# 4                           water
# ...                           ...
# 11676       acute gastroenteritis
# 11677                         nec
# 11678                         nec
# 11679                   cirrhosis
# 11680                      asthma
#
# [3504381 rows x 25 columns]

# %% [markdown]
# after doing the replacement would be nice to redo the clustering again to see if there are some that should be changed manually and do this in the replacement part in `rel_pred.smk`
