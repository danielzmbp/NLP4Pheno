# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## NER

# %%
ner_aug = pd.read_csv("augmentation_files/run_aug/NER_output/aggregated_eval.tsv",sep="\t",index_col=0)
ner_nonaug = pd.read_csv("augmentation_files/run_nonaug/NER_output/aggregated_eval.tsv",sep="\t",index_col=0)

# %%
(ner_aug.test_f1 -ner_nonaug.test_f1).mean()
# Out:
# np.float64(0.0033065268329753347)

# %% [markdown]
# ## RE

# %%
re_aug = pd.read_csv("augmentation_files/run_aug/REL_output/all_metrics.tsv",sep="\t",index_col=0)
re_nonaug = pd.read_csv("augmentation_files/run_nonaug/REL_output/all_metrics.tsv",sep="\t",index_col=0)

# %%
(re_aug.test_F1 -re_nonaug.test_F1).mean()
# Out:
# np.float64(0.020838569651516863)
